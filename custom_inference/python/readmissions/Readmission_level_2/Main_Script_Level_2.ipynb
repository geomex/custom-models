# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import joblib
import numpy as np
import json
# !pip install xgboost
from xgboost import XGBClassifier

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
# Out:
# Collecting xgboost
#   Downloading xgboost-1.4.2-py3-none-macosx_10_14_x86_64.macosx_10_15_x86_64.macosx_11_0_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 2.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.19.2)
# Requirement already satisfied: scipy in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from xgboost) (1.6.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.4.2
# -------------------------------------------------------------
# XGBoostError                Traceback (most recent call last)
# <ipython-input-2-6adc3080d161> in <module>
#       4 import json
#       5 get_ipython().system('pip install xgboost')
# ----> 6 from xgboost import XGBClassifier
#       7
#       8 from sklearn.pipeline import Pipeline
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in <module>
#     193
#     194 # load the XGBoost library globally
# --> 195 _LIB = _load_lib()
#     196
#     197
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in _load_lib()
#     176     if not lib_success:
#     177         libname = os.path.basename(lib_paths[0])
# --> 178         raise XGBoostError(
#     179             'XGBoost Library ({}) could not be loaded.\n'.format(libname) +
#     180             'Likely causes:\n' +
#
# XGBoostError: XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ['dlopen(/Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']

# %%
#In case I need to update datarobot-drum
# !pip install datarobot-drum --upgrade
# Out:
# Collecting datarobot-drum
#   Using cached datarobot_drum-1.5.11-py3-none-any.whl (8.8 MB)
# Requirement already satisfied: scipy<2,>=1.1 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (1.6.2)
# Collecting datarobot==2.24.0
#   Using cached datarobot-2.24.0-py3-none-any.whl (418 kB)
# Collecting progress
#   Using cached progress-1.6-py3-none-any.whl
# Requirement already satisfied: requests in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (2.25.1)
# Collecting strictyaml==1.4.2
#   Using cached strictyaml-1.4.2-py3-none-any.whl
# Requirement already satisfied: jinja2 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (2.11.3)
# Requirement already satisfied: flask in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (1.1.2)
# Collecting docker>=4.2.2<5.0.0
#   Using cached docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting texttable
#   Using cached texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: Pillow==8.2.0 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (8.2.0)
# Collecting memory-profiler<1.0.0
#   Using cached memory_profiler-0.58.0-py3-none-any.whl
# Collecting julia==0.5.6
#   Using cached julia-0.5.6-py2.py3-none-any.whl (67 kB)
# Collecting py4j~=0.10.9.0
#   Using cached py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
# Collecting mlpiper~=2.4.0
#   Using cached mlpiper-2.4.2-py2.py3-none-any.whl (781 kB)
# Collecting argcomplete==1.11.1
#   Using cached argcomplete-1.11.1-py2.py3-none-any.whl (36 kB)
# Collecting pyarrow==2.0.0
#   Using cached pyarrow-2.0.0-cp38-cp38-macosx_10_13_x86_64.whl (13.4 MB)
# Requirement already satisfied: numpy in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (1.19.2)
# Requirement already satisfied: pandas<1.3.1,>=1.0.5 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot-drum) (1.2.4)
# Requirement already satisfied: attrs<20.0,>=19.1.0 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (19.3.0)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (0.6.0.post1)
# Requirement already satisfied: pyyaml>=3.11 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (5.4.1)
# Requirement already satisfied: requests-toolbelt>=0.6 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (0.9.1)
# Requirement already satisfied: urllib3>=1.23 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (1.26.4)
# Requirement already satisfied: trafaret!=1.1.0,<2.0,>=0.7 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from datarobot==2.24.0->datarobot-drum) (1.2.0)
# Collecting ruamel.yaml==0.17.4
#   Using cached ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Requirement already satisfied: python-dateutil>=2.6.0 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from strictyaml==1.4.2->datarobot-drum) (2.8.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from ruamel.yaml==0.17.4->strictyaml==1.4.2->datarobot-drum) (0.2.6)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from docker>=4.2.2<5.0.0->datarobot-drum) (1.2.1)
# Requirement already satisfied: psutil in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from memory-profiler<1.0.0->datarobot-drum) (5.8.0)
# Collecting flask-cors
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: future in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from mlpiper~=2.4.0->datarobot-drum) (0.18.2)
# Requirement already satisfied: termcolor in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from mlpiper~=2.4.0->datarobot-drum) (1.1.0)
# Collecting uwsgi
#   Using cached uWSGI-2.0.19.1.tar.gz (803 kB)
# Requirement already satisfied: pytz>=2017.3 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from pandas<1.3.1,>=1.0.5->datarobot-drum) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.0->strictyaml==1.4.2->datarobot-drum) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from requests->datarobot-drum) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from requests->datarobot-drum) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from requests->datarobot-drum) (2.10)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from flask->datarobot-drum) (1.1.0)
# Requirement already satisfied: click>=5.1 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from flask->datarobot-drum) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from flask->datarobot-drum) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages (from jinja2->datarobot-drum) (1.1.1)
# Building wheels for collected packages: uwsgi
#   Building wheel for uwsgi (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/joel.gongora/opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"'; __file__='"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-wheel-0to38aog
#        cwd: /private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/
#   Complete output (42 lines):
#   /Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'descriptions'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   copying uwsgidecorators.py -> build/lib
#   installing to build/bdist.macosx-10.9-x86_64/wheel
#   running install
#   using profile: buildconf/default.ini
#   detected include path: ['/usr/local/include', '/Applications/Xcode.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/lib/clang/12.0.5/include', '/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk/usr/include', '/Applications/Xcode.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/include', '/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk/System/Library/Frameworks']
#   Traceback (most recent call last):
#     File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/uwsgiconfig.py", line 747, in __init__
#       gcc_version_components = gcc_version.split('.')
#   AttributeError: 'NoneType' object has no attribute 'split'
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py", line 117, in <module>
#       setup(
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 335, in run
#       self.run_command('install')
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py", line 77, in run
#       conf = uc.uConf(get_profile())
#     File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/uwsgiconfig.py", line 755, in __init__
#       raise Exception("you need a C compiler to build uWSGI")
#   Exception: you need a C compiler to build uWSGI
#   ----------------------------------------
#   ERROR: Failed building wheel for uwsgi
#   Running setup.py clean for uwsgi
# Failed to build uwsgi
# Installing collected packages: uwsgi, ruamel.yaml, py4j, flask-cors, texttable, strictyaml, pyarrow, progress, mlpiper, memory-profiler, julia, docker, datarobot, argcomplete, datarobot-drum
#     Running setup.py install for uwsgi ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/joel.gongora/opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"'; __file__='"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-record-70x__3au/install-record.txt --single-version-externally-managed --compile --install-headers /Users/joel.gongora/opt/anaconda3/include/python3.8/uwsgi
#          cwd: /private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/
#     Complete output (29 lines):
#     /Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'descriptions'
#       warnings.warn(msg)
#     running install
#     using profile: buildconf/default.ini
#     detected include path: ['/usr/local/include', '/Applications/Xcode.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/lib/clang/12.0.5/include', '/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk/usr/include', '/Applications/Xcode.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/include', '/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk/System/Library/Frameworks']
#     Traceback (most recent call last):
#       File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/uwsgiconfig.py", line 747, in __init__
#         gcc_version_components = gcc_version.split('.')
#     AttributeError: 'NoneType' object has no attribute 'split'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py", line 117, in <module>
#         setup(
#       File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/Users/joel.gongora/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py", line 77, in run
#         conf = uc.uConf(get_profile())
#       File "/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/uwsgiconfig.py", line 755, in __init__
#         raise Exception("you need a C compiler to build uWSGI")
#     Exception: you need a C compiler to build uWSGI
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/joel.gongora/opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"'; __file__='"'"'/private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-install-yskpc8cs/uwsgi_ddd2e4e2bac3428a8a9fac939071c7cb/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/nz/89yd1h313yn8t9lr6lw41zf80000gq/T/pip-record-70x__3au/install-record.txt --single-version-externally-managed --compile --install-headers /Users/joel.gongora/opt/anaconda3/include/python3.8/uwsgi Check the logs for full command output.

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('../data/readmissions_train.csv')

X = train.drop('readmitted',axis=1)
X.drop(['diag_1_desc', 'diag_1', 'diag_2', 'diag_3'],axis=1,inplace=True)
y = train.pop('readmitted')

# %% [markdown]
# ### Define Preprocessing step per type of column

# %%
#Preprocessing for numerical features
numeric_features = list(X.select_dtypes('int64').columns)
for c in numeric_features:
    X[c] = X[c].fillna(0)
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

#Preprocessing for categorical features
categorical_features = list(X.select_dtypes('object').columns)
for c in categorical_features:
    X[c] = X[c].fillna('missing')
categorical_transformer = Pipeline(steps=[
    ('OneHotEncoder', OneHotEncoder(handle_unknown='ignore'))])

#Preprocessor with all of the steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# <ipython-input-5-7056892bed2b> in <module>
#       3 for c in numeric_features:
#       4     X[c] = X[c].fillna(0)
# ----> 5 numeric_transformer = Pipeline(steps=[
#       6     ('scaler', StandardScaler())])
#       7
#
# NameError: name 'Pipeline' is not defined

# %% [markdown]
# ### Fit the Preprocessing Pipeline

# %%
# Full preprocessing pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

#Train the model-Pipeline
pipeline.fit(X,y)

#Preprocess x
preprocessed = pipeline.transform(X)

#I could also train the model with the sparse matrix. I transform it to padnas because the hook function in custom.py expected a pandas dataframe to be used for scoring.
preprocessed = pd.DataFrame.sparse.from_spmatrix(preprocessed)

# %% [markdown]
# ### Train XGboost Classifier
# Normally, the XGboost classifier could be part of the final scikit-learn pipeline. I am opting to keep them separate in order to create a more complicated example with different pkl files for preprocessing and scoring

# %%
model = XGBClassifier(colsample_bylevel=0.2, max_depth= 10, learning_rate = 0.02, n_estimators=300)
model.fit(preprocessed, y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=0.2,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.02, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Save Custom Model files

# %%
joblib.dump(pipeline,'custom_model/preprocessing.pkl')
joblib.dump(model, 'custom_model/model.pkl')
# Out:
# ['custom_model/model.pkl']

# %%
# !drum validation --code-dir ./custom_model --input ../data/readmissions_test.csv --target-type binary --positive-class-label True --negative-class-label False
# Out:
#          True     False
# 0    0.615392  0.384608
# 1    0.716724  0.283276
# 2    0.652516  0.347484
# 3    0.614488  0.385512
# 4    0.819258  0.180742
# ..        ...       ...
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.526473  0.473526
# 1    0.723336  0.276664
# 2    0.687653  0.312347
# 3    0.618998  0.381002
# 4    0.816318  0.183682
# ..        ...       ...
# 495  0.575147  0.424853
# 496  0.451384  0.548616
# 497  0.488106  0.511894
# 498  0.479366  0.520634
# 499  0.347125  0.652876
#
# [500 rows x 2 columns]
#          True     False
# 0    0.531242  0.468758
# 1    0.716431  0.283569
# 2    0.651989  0.348011
# 3    0.616853  0.383147
# 4    0.817853  0.182147
# ..        ...       ...
# 495  0.600144  0.399856
# 496  0.456822  0.543178
# 497  0.481419  0.518581
# 498  0.477997  0.522003
# 499  0.348629  0.651371
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.494622  0.505378
# 1    0.717189  0.282812
# 2    0.633874  0.366126
# 3    0.597888  0.402112
# 4    0.807893  0.192107
# ..        ...       ...
# 495  0.552908  0.447092
# 496  0.445508  0.554492
# 497  0.471288  0.528712
# 498  0.457871  0.542129
# 499  0.277426  0.722574
#
# [500 rows x 2 columns]
#          True     False
# 0    0.546007  0.453993
# 1    0.717022  0.282978
# 2    0.638685  0.361315
# 3    0.616853  0.383147
# 4    0.830499  0.169501
# ..        ...       ...
# 495  0.581854  0.418146
# 496  0.448176  0.551824
# 497  0.459571  0.540429
# 498  0.468551  0.531449
# 499  0.348309  0.651691
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.526894  0.473106
# 1    0.729752  0.270248
# 2    0.702171  0.297829
# 3    0.610631  0.389369
# 4    0.802278  0.197722
# ..        ...       ...
# 495  0.574052  0.425948
# 496  0.459275  0.540725
# 497  0.455178  0.544822
# 498  0.493760  0.506240
# 499  0.352454  0.647546
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.713091  0.286909
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.810370  0.189630
# ..        ...       ...
# 495  0.589422  0.410578
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#          True     False
# 0    0.549206  0.450794
# 1    0.725911  0.274089
# 2    0.649655  0.350345
# 3    0.610034  0.389966
# 4    0.814222  0.185778
# ..        ...       ...
# 495  0.592178  0.407822
# 496  0.478022  0.521978
# 497  0.490359  0.509641
# 498  0.465928  0.534072
# 499  0.371898  0.628102
#
# [500 rows x 2 columns]
#          True     False
# 0    0.535857  0.464143
# 1    0.725520  0.274480
# 2    0.637735  0.362265
# 3    0.622865  0.377135
# 4    0.818635  0.181365
# ..        ...       ...
# 495  0.600550  0.399450
# 496  0.451195  0.548805
# 497  0.460050  0.539950
# 498  0.494688  0.505312
# 499  0.362967  0.637033
#
# [500 rows x 2 columns]
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
#
#
# Validation checks results
#       Test case         Status
# ==============================
# Null value imputation   PASSED

# %% [markdown]
# ### Validate model can work as `Custom Training Model`

# %%
# !drum fit --code-dir ./custom_model --input ../data/readmissions_train.csv --target-type binary --target readmitted --positive-class-label True --negative-class-label False
# Out:
# Files were overwritten: {'/var/folders/v3/1cwf1zz90_nczrfzhvxwyjfr0000gp/T/tmpvnquru3s/model.pkl', '/var/folders/v3/1cwf1zz90_nczrfzhvxwyjfr0000gp/T/tmpvnquru3s/preprocessing.pkl'}
# Validation Complete 🎉 Your model can be fit to your data,  and predictions can be made on the fit model!
#  You're ready to add it to DataRobot.

# %%
# !drum score --code-dir ./custom_model --input ../data/readmissions_test.csv --target-type binary --positive-class-label True --negative-class-label False
# Out:
#          True     False
# 0    0.532502  0.467498
# 1    0.716724  0.283276
# 2    0.655804  0.344196
# 3    0.616853  0.383147
# 4    0.816218  0.183782
# ..        ...       ...
# 495  0.586178  0.413822
# 496  0.458597  0.541403
# 497  0.466822  0.533178
# 498  0.478825  0.521175
# 499  0.349466  0.650534
#
# [500 rows x 2 columns]
