# %%
# !pip install -U --no-deps datarobot-drum
# !pip install datarobot
# !pip install PyYAML
# !pip install strictyaml
# !pip install memory_profiler
# !pip install flask
# !pip install -U --no-deps mlpiper
# !pip install future
# !pip install py4j
# !pip install progress
# !pip install texttable
# !pip install docker
# !pip install pyarrow
# !pip install argcomplete
# !pip install termcolor
# !pip install tensorflow
# Out:
# Collecting datarobot-drum
#   Using cached datarobot_drum-1.5.11-py3-none-any.whl (8.8 MB)
# Installing collected packages: datarobot-drum
# Successfully installed datarobot-drum-1.5.11
# Requirement already satisfied: datarobot in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (2.25.1)
# Requirement already satisfied: requests-toolbelt>=0.6 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (0.9.1)
# Requirement already satisfied: pandas<1.3.1,>=0.15 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (1.1.5)
# Collecting attrs<20.0,>=19.1.0
#   Using cached attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: contextlib2>=0.5.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (21.6.0)
# Requirement already satisfied: urllib3>=1.23 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (1.26.6)
# Requirement already satisfied: pyyaml>=3.11 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (5.4.1)
# Requirement already satisfied: trafaret!=1.1.0,<2.0,>=0.7 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (1.2.0)
# Requirement already satisfied: requests>=2.21 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from datarobot) (2.26.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from pandas<1.3.1,>=0.15->datarobot) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from pandas<1.3.1,>=0.15->datarobot) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from pandas<1.3.1,>=0.15->datarobot) (2021.1)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests>=2.21->datarobot) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests>=2.21->datarobot) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests>=2.21->datarobot) (2.0.4)
# Requirement already satisfied: six>=1.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas<1.3.1,>=0.15->datarobot) (1.16.0)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 20.2.0
#     Uninstalling attrs-20.2.0:
#       Successfully uninstalled attrs-20.2.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires flask, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires memory-profiler<1.0.0, which is not installed.
# datarobot-drum 1.5.11 requires mlpiper~=2.4.0, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires progress, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, which is not installed.
# datarobot-drum 1.5.11 requires texttable, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# Successfully installed attrs-19.3.0
# Requirement already satisfied: PyYAML in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (5.4.1)
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/bc/4f/b9/779b25e4d5fa14dda43cac46d0c5bc349abb95f96e9371c0ff/strictyaml-1.4.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.6.0 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from strictyaml) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from python-dateutil>=2.6.0->strictyaml) (1.16.0)
# Installing collected packages: strictyaml
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires flask, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires memory-profiler<1.0.0, which is not installed.
# datarobot-drum 1.5.11 requires mlpiper~=2.4.0, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires progress, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires texttable, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed strictyaml-1.4.4
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/02/e4/0b/aaab481fc5dd2a4ea59e78bc7231bb6aae7635ca7ee79f8ae5/memory_profiler-0.58.0-cp37-none-any.whl
# Collecting psutil
#   Using cached psutil-5.8.0-cp37-cp37m-macosx_10_9_x86_64.whl (236 kB)
# Installing collected packages: psutil, memory-profiler
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires flask, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires mlpiper~=2.4.0, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires progress, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires texttable, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed memory-profiler-0.58.0 psutil-5.8.0
# Collecting flask
#   Using cached Flask-2.0.1-py3-none-any.whl (94 kB)
# Collecting click>=7.1.2
#   Using cached click-8.0.1-py3-none-any.whl (97 kB)
# Collecting Werkzeug>=2.0
#   Using cached Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=3.0
#   Using cached Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from click>=7.1.2->flask) (2.0.0)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->click>=7.1.2->flask) (3.3.1)
# Installing collected packages: click, Werkzeug, itsdangerous, MarkupSafe, Jinja2, flask
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires mlpiper~=2.4.0, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires progress, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires texttable, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 Werkzeug-2.0.1 click-8.0.1 flask-2.0.1 itsdangerous-2.0.1
# Collecting mlpiper
#   Using cached mlpiper-2.4.2-py2.py3-none-any.whl (781 kB)
# Installing collected packages: mlpiper
# Successfully installed mlpiper-2.4.2
# Requirement already satisfied: future in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (0.18.2)
# Requirement already satisfied: py4j in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (0.10.9.2)
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/f7/77/62/8009c7b01d897696ce78411c960feef470deba85601493bf67/progress-1.6-cp37-none-any.whl
# Installing collected packages: progress
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires texttable, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed progress-1.6
# Collecting texttable
#   Using cached texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires docker>=4.2.2<5.0.0, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed texttable-1.6.4
# Collecting docker
#   Using cached docker-5.0.2-py2.py3-none-any.whl (145 kB)
# Collecting websocket-client>=0.32.0
#   Using cached websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from docker) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker) (2020.6.20)
# Installing collected packages: websocket-client, docker
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed docker-5.0.2 websocket-client-1.2.1
# Collecting pyarrow
#   Using cached pyarrow-5.0.0-cp37-cp37m-macosx_10_13_x86_64.whl (17.6 MB)
# Requirement already satisfied: numpy>=1.16.6 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from pyarrow) (1.21.2)
# Installing collected packages: pyarrow
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, but you'll have pyarrow 5.0.0 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed pyarrow-5.0.0
# Collecting argcomplete
#   Using cached argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: importlib-metadata<5,>=0.23; python_version == "3.7" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from argcomplete) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from importlib-metadata<5,>=0.23; python_version == "3.7"->argcomplete) (3.3.1)
# Installing collected packages: argcomplete
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, but you'll have argcomplete 1.12.3 which is incompatible.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, but you'll have pyarrow 5.0.0 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed argcomplete-1.12.3
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6/termcolor-1.1.0-cp37-none-any.whl
# Installing collected packages: termcolor
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# mlpiper 2.4.2 requires flask-cors, which is not installed.
# mlpiper 2.4.2 requires uwsgi; sys_platform != "win32", which is not installed.
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, but you'll have argcomplete 1.12.3 which is incompatible.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, but you'll have pyarrow 5.0.0 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed termcolor-1.1.0
# Collecting tensorflow
#   Using cached tensorflow-2.6.0-cp37-cp37m-macosx_10_11_x86_64.whl (198.9 MB)
# Collecting grpcio<2.0,>=1.37.0
#   Using cached grpcio-1.39.0-cp37-cp37m-macosx_10_10_x86_64.whl (3.9 MB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting keras~=2.6
#   Using cached keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp37-cp37m-macosx_10_9_x86_64.whl (15.6 MB)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/98/91/04/971b4c587cf47ae952b108949b46926f426c02832d120a082a/clang-5.0-py3-none-any.whl
# Collecting tensorflow-estimator~=2.6
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.17.3-cp37-cp37m-macosx_10_9_x86_64.whl (1.0 MB)
# Requirement already satisfied: wheel~=0.35 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from tensorflow) (0.35.1)
# Processing /Users/joel.gongora/Library/Caches/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6/wrapt-1.12.1-py3-none-any.whl
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp37-cp37m-macosx_10_9_x86_64.whl (2.9 MB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (50.3.0.post20201006)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from tensorboard~=2.6->tensorflow) (2.0.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting cached-property; python_version < "3.8"
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.6.20)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/joel.gongora/opt/anaconda3/envs/drum_corrected/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.3.1)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: six, grpcio, gast, numpy, keras-preprocessing, markdown, tensorboard-plugin-wit, absl-py, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, protobuf, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-data-server, tensorboard, google-pasta, typing-extensions, keras, clang, tensorflow-estimator, wrapt, astunparse, cached-property, h5py, opt-einsum, flatbuffers, tensorflow
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# datarobot-drum 1.5.11 requires julia==0.5.6, which is not installed.
# datarobot-drum 1.5.11 requires Pillow==8.2.0, which is not installed.
# datarobot-drum 1.5.11 requires argcomplete==1.11.1, but you'll have argcomplete 1.12.3 which is incompatible.
# datarobot-drum 1.5.11 requires datarobot==2.24.0, but you'll have datarobot 2.25.1 which is incompatible.
# datarobot-drum 1.5.11 requires pyarrow==2.0.0, but you'll have pyarrow 5.0.0 which is incompatible.
# datarobot-drum 1.5.11 requires strictyaml==1.4.2, but you'll have strictyaml 1.4.4 which is incompatible.
# Successfully installed absl-py-0.13.0 astunparse-1.6.3 cached-property-1.5.2 cachetools-4.2.2 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.39.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.4 numpy-1.19.5 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.6.0 tensorflow-estimator-2.6.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import io

# %% [markdown]
# ## DRUM

# %%
# !drum --version
# Out:
# drum 1.5.11

# %%
# !drum --help
# Out:
# usage: drum [-h] [--version]
#             {score,fit,perf-test,validation,server,new,push} ...
#
# Run user model
#
# positional arguments:
#   {score,fit,perf-test,validation,server,new,push}
#                         Commands
#     score               Run predictions in batch mode
#     fit                 Fit your model to your data
#     perf-test           Run performance tests
#     validation          Run validation checks against the model
#     server              serve the model via REST APIs
#     new                 Create new model/env template
#     push                Add your modeling code into DataRobot
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit

# %% [markdown]
# ## Validate

# %%
# !drum validation --code-dir recommender_model \
--input predict.csv \
--target-type unstructured
# Out:
# usage: drum validation [-h] -cd CODE_DIR --input INPUT
#                        [--positive-class-label POSITIVE_CLASS_LABEL]
#                        [--negative-class-label NEGATIVE_CLASS_LABEL]
#                        [--class-labels CLASS_LABELS [CLASS_LABELS ...]]
#                        [--class-labels-file CLASS_LABELS_FILE]
#                        [--docker DOCKER] [--skip-deps-install]
#                        [--memory MEMORY] [--language {python,r,java,julia}]
#                        [--show-stacktrace]
#                        [--target-type {binary,multiclass,regression,anomaly,unstructured,transform}]
#                        [--query QUERY] [--content-type CONTENT_TYPE]
# drum validation: error: argument --input: The file predict.csv does not exist!

# %% [markdown]
# ## Score

# %%
# !drum score --code-dir recommender_model \
--input recommender_model/predict.csv \
--target-type unstructured
# Out:
# 2020-12-16 09:29:03.573565: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-16 09:29:03.585352: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc2cce4ba70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-16 09:29:03.585369: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# movieId,title,genres
# 279,My Family (1995),Drama
# 848,"Spitfire Grill, The (1996)",Drama
# 943,"Ghost and Mrs. Muir, The (1947)",Drama|Fantasy|Romance
# 1464,Lost Highway (1997),Crime|Drama|Fantasy|Film-Noir|Mystery|Romance
# 1681,Mortal Kombat: Annihilation (1997),Action|Adventure|Fantasy
# 2660,"Thing from Another World, The (1951)",Horror|Sci-Fi
# 2661,It Came from Outer Space (1953),Sci-Fi
# 6382,Together (Han ni Zai Yiki) (2002),Drama
# 34271,Hustle & Flow (2005),Crime|Drama
# 39414,Shopgirl (2005),Comedy|Drama|Romance
